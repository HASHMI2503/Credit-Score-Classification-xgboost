# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-score-classification-86-features/cibil dataset.xlsx
# /kaggle/input/credit-score-classification-86-features/cibil_and_bank.xlsx
# /kaggle/input/credit-score-classification-86-features/only_imp_final_features.xlsx
# /kaggle/input/credit-score-classification-86-features/bank internal dataset.xlsx

# %% [markdown]
# ## Summary of Steps
#
# 1. **Data Preparation**:
#    - Load data from Excel files and merge them.
#    - Handle missing values by dropping rows with specific values.
#
# 2. **Feature Selection**:
#    - Use chi-square test for categorical features and ANOVA for numerical features.
#    - Retain features with significant associations with the target variable.
#
# 3. **Data Encoding**:
#    - Label encode categorical features and perform ordinal encoding for 'EDUCATION'.
#    - Apply one-hot encoding to convert categorical features into binary format.
#
# 4. **Machine Learning Model Fitting**:
#    - Train Random Forest, Decision Tree, and XGBoost classifiers.
#    - Evaluate model performance using accuracy, precision, recall, and F1-score.
#
# 5. **Model Improvement**:
#    - Explore hyperparameter tuning for the XGBoost classifier using techniques like grid search.
#    - Perform a wide search over combinations of hyperparameters, e.g., around 900 combinations, to find optimal settings for the XGBoost model.
#
# 6. **XGBoost Model Improvement**:
#
# This XGBoost setup stands out:
#
# - **colsample_bytree:** 0.9
# - **learning_rate:** 1
# - **max_depth:** 3
# - **alpha:** 1
# - **n_estimators:** 50
#
# Achieving 81% accuracy on the training set and 78% on the testing set.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from scipy.stats import chi2_contingency
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support
import warnings
import os

# %% [markdown]
# 1. **Data Preparation**:

# %%
df1 = pd.read_excel("/kaggle/input/credit-score-classification-86-features/bank internal dataset.xlsx")
df2 = pd.read_excel("/kaggle/input/credit-score-classification-86-features/cibil dataset.xlsx")

# %%
df1.shape
df2.shape
# Out:
# (51336, 62)

# %%
df1.columns
df2.columns
# Out:
# Index(['PROSPECTID', 'time_since_recent_payment',
#        'time_since_first_deliquency', 'time_since_recent_deliquency',
#        'num_times_delinquent', 'max_delinquency_level',
#        'max_recent_level_of_deliq', 'num_deliq_6mts', 'num_deliq_12mts',
#        'num_deliq_6_12mts', 'max_deliq_6mts', 'max_deliq_12mts',
#        'num_times_30p_dpd', 'num_times_60p_dpd', 'num_std', 'num_std_6mts',
#        'num_std_12mts', 'num_sub', 'num_sub_6mts', 'num_sub_12mts', 'num_dbt',
#        'num_dbt_6mts', 'num_dbt_12mts', 'num_lss', 'num_lss_6mts',
#        'num_lss_12mts', 'recent_level_of_deliq', 'tot_enq', 'CC_enq',
#        'CC_enq_L6m', 'CC_enq_L12m', 'PL_enq', 'PL_enq_L6m', 'PL_enq_L12m',
#        'time_since_recent_enq', 'enq_L12m', 'enq_L6m', 'enq_L3m',
#        'MARITALSTATUS', 'EDUCATION', 'AGE', 'GENDER', 'NETMONTHLYINCOME',
#        'Time_With_Curr_Empr', 'pct_of_active_TLs_ever',
#        'pct_opened_TLs_L6m_of_L12m', 'pct_currentBal_all_TL', 'CC_utilization',
#        'CC_Flag', 'PL_utilization', 'PL_Flag', 'pct_PL_enq_L6m_of_L12m',
#        'pct_CC_enq_L6m_of_L12m', 'pct_PL_enq_L6m_of_ever',
#        'pct_CC_enq_L6m_of_ever', 'max_unsec_exposure_inPct', 'HL_Flag',
#        'GL_Flag', 'last_prod_enq2', 'first_prod_enq2', 'Credit_Score',
#        'Approved_Flag'],
#       dtype='object')

# %%
# We noticed that the Age_Oldest_TL column has a lot of missing values, so we're going to remove it from the dataset.
df1 = df1.loc[df1['Age_Oldest_TL'] != -99999 ]

# %%
# Removes columns that contain more than 10,000 instances of the null value.
coloums_to_be_removed = []

for i in df2.columns:
    if df2.loc[df2[i] == -99999].shape[0] > 10000:
        coloums_to_be_removed.append(i)
        
df2 = df2.drop(coloums_to_be_removed , axis = 1)

df2.shape
# Out:
# (51336, 54)

# %%
# Removes rows with null values for any column.
for i in df2.columns:
    df2 = df2.loc[df2[i] != -99999]

df2.shape
# Out:
# (42066, 54)

# %%
df1.isna().sum()
# Out:
# PROSPECTID              0
# Total_TL                0
# Tot_Closed_TL           0
# Tot_Active_TL           0
# Total_TL_opened_L6M     0
# Tot_TL_closed_L6M       0
# pct_tl_open_L6M         0
# pct_tl_closed_L6M       0
# pct_active_tl           0
# pct_closed_tl           0
# Total_TL_opened_L12M    0
# Tot_TL_closed_L12M      0
# pct_tl_open_L12M        0
# pct_tl_closed_L12M      0
# Tot_Missed_Pmnt         0
# Auto_TL                 0
# CC_TL                   0
# Consumer_TL             0
# Gold_TL                 0
# Home_TL                 0
# PL_TL                   0
# Secured_TL              0
# Unsecured_TL            0
# Other_TL                0
# Age_Oldest_TL           0
# Age_Newest_TL           0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# PROSPECTID                    0
# time_since_recent_payment     0
# num_times_delinquent          0
# max_recent_level_of_deliq     0
# num_deliq_6mts                0
# num_deliq_12mts               0
# num_deliq_6_12mts             0
# num_times_30p_dpd             0
# num_times_60p_dpd             0
# num_std                       0
# num_std_6mts                  0
# num_std_12mts                 0
# num_sub                       0
# num_sub_6mts                  0
# num_sub_12mts                 0
# num_dbt                       0
# num_dbt_6mts                  0
# num_dbt_12mts                 0
# num_lss                       0
# num_lss_6mts                  0
# num_lss_12mts                 0
# recent_level_of_deliq         0
# tot_enq                       0
# CC_enq                        0
# CC_enq_L6m                    0
# CC_enq_L12m                   0
# PL_enq                        0
# PL_enq_L6m                    0
# PL_enq_L12m                   0
# time_since_recent_enq         0
# enq_L12m                      0
# enq_L6m                       0
# enq_L3m                       0
# MARITALSTATUS                 0
# EDUCATION                     0
# AGE                           0
# GENDER                        0
# NETMONTHLYINCOME              0
# Time_With_Curr_Empr           0
# pct_of_active_TLs_ever        0
# pct_opened_TLs_L6m_of_L12m    0
# pct_currentBal_all_TL         0
# CC_Flag                       0
# PL_Flag                       0
# pct_PL_enq_L6m_of_L12m        0
# pct_CC_enq_L6m_of_L12m        0
# pct_PL_enq_L6m_of_ever        0
# pct_CC_enq_L6m_of_ever        0
# HL_Flag                       0
# GL_Flag                       0
# last_prod_enq2                0
# first_prod_enq2               0
# Credit_Score                  0
# Approved_Flag                 0
# dtype: int64

# %%
# Finding which columns are common between the datasets.
for i in list(df1.columns):
    if i in list(df2.columns):
        print(i)
# Out:
# PROSPECTID

# %%
df = pd.merge(df1 , df2 , how="inner" , left_on = ["PROSPECTID"] , right_on = ["PROSPECTID"])

# %%
df.shape
# Out:
# (42064, 79)

# %%
#df.to_excel('cibil_and_bank.xlsx', index=False)

# %% [markdown]
# 2. **Feature Selection**:

# %%
# Columns in df that contain categorical data
for i in df.columns:
    if df[i].dtype == 'object':
        print(i)
# Out:
# MARITALSTATUS
# EDUCATION
# GENDER
# last_prod_enq2
# first_prod_enq2
# Approved_Flag

# %%
from scipy.stats import chi2_contingency

# %%
# Every feature tested shows Association with the 'Approved_Flag', so we will retain all of them.
for i in ['MARITALSTATUS', 'EDUCATION', 'GENDER', 'last_prod_enq2', 'first_prod_enq2']:
    chi2, pval, _, _ = chi2_contingency(pd.crosstab(df[i], df['Approved_Flag']))
    print(i, '---', pval)
# Out:
# MARITALSTATUS --- 3.578180861038862e-233
# EDUCATION --- 2.6942265249737532e-30
# GENDER --- 1.907936100186563e-05
# last_prod_enq2 --- 0.0
# first_prod_enq2 --- 7.84997610555419e-287

# %%
numeric_columns = []
for i in df.columns:
    if df[i].dtype != 'object' and i not in ['PROSPECTID','Approved_Flag']:
        numeric_columns.append(i)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = df[numeric_columns]
total_columns = vif_data.shape[1]
columns_to_be_kept = []
column_index = 0

# %%
for i in range (0,total_columns):
    
    vif_value = variance_inflation_factor(vif_data, column_index)
    print (column_index,'---',vif_value)
    
    
    if vif_value <= 6:
        columns_to_be_kept.append( numeric_columns[i] )
        column_index = column_index+1
    
    else:
        vif_data = vif_data.drop([ numeric_columns[i] ] , axis=1)
# Out:
# /opt/conda/lib/python3.10/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 0 --- inf
# /opt/conda/lib/python3.10/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 0 --- inf
# 0 --- 11.320180023967996
# 0 --- 8.363698035000336
# 0 --- 6.520647877790928
# 0 --- 5.149501618212625
# 1 --- 2.611111040579735
# /opt/conda/lib/python3.10/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 2 --- inf
# 2 --- 1788.7926256209232
# 2 --- 8.601028256477228
# 2 --- 3.8328007921530785
# 3 --- 6.0996533816467355
# 3 --- 5.581352009642762
# 4 --- 1.985584353098778
# /opt/conda/lib/python3.10/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 5 --- inf
# 5 --- 4.809538302819343
# 6 --- 23.270628983464636
# 6 --- 30.595522588100053
# 6 --- 4.3843464059655854
# 7 --- 3.0646584155234238
# 8 --- 2.898639771299252
# 9 --- 4.377876915347322
# 10 --- 2.207853583695844
# 11 --- 4.916914200506864
# 12 --- 5.214702030064725
# 13 --- 3.3861625024231476
# 14 --- 7.840583309478997
# 14 --- 5.255034641721434
# /opt/conda/lib/python3.10/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 15 --- inf
# 15 --- 7.380634506427232
# 15 --- 1.4210050015175733
# 16 --- 8.083255010190323
# 16 --- 1.6241227524040114
# 17 --- 7.257811920140003
# 17 --- 15.59624383268298
# 17 --- 1.825857047132431
# 18 --- 1.5080839450032661
# 19 --- 2.172088834824578
# 20 --- 2.6233975535272305
# 21 --- 2.2959970812106167
# 22 --- 7.360578319196446
# 22 --- 2.1602387773102554
# 23 --- 2.8686288267891467
# 24 --- 6.458218003637272
# 24 --- 2.8474118865638265
# 25 --- 4.7531981562840855
# 26 --- 16.227354755948223
# 26 --- 6.424377256363877
# 26 --- 8.887080381808687
# 26 --- 2.3804746142952653
# 27 --- 8.609513476514548
# 27 --- 13.06755093547673
# 27 --- 3.5000400566546555
# 28 --- 1.908795587481377
# 29 --- 17.006562234161628
# 29 --- 10.730485153719197
# 29 --- 2.3538497522950275
# 30 --- 22.104855915136433
# 30 --- 2.7971639638512906
# 31 --- 3.424171203217696
# 32 --- 10.175021454450935
# 32 --- 6.408710354561301
# 32 --- 1.001151196262562
# 33 --- 3.069197305397274
# 34 --- 2.8091261600643724
# 35 --- 20.249538381980678
# 35 --- 15.864576541593745
# 35 --- 1.8331649740532168
# 36 --- 1.5680839909542046
# 37 --- 1.9307572353811677
# 38 --- 4.331265056645244
# 39 --- 9.390334396150173

# %%
columns_to_be_kept
# Out:
# ['pct_tl_open_L6M',
#  'pct_tl_closed_L6M',
#  'Tot_TL_closed_L12M',
#  'pct_tl_closed_L12M',
#  'Tot_Missed_Pmnt',
#  'CC_TL',
#  'Home_TL',
#  'PL_TL',
#  'Secured_TL',
#  'Unsecured_TL',
#  'Other_TL',
#  'Age_Oldest_TL',
#  'Age_Newest_TL',
#  'time_since_recent_payment',
#  'max_recent_level_of_deliq',
#  'num_deliq_6_12mts',
#  'num_times_60p_dpd',
#  'num_std_12mts',
#  'num_sub',
#  'num_sub_6mts',
#  'num_sub_12mts',
#  'num_dbt',
#  'num_dbt_12mts',
#  'num_lss',
#  'num_lss_12mts',
#  'recent_level_of_deliq',
#  'CC_enq_L12m',
#  'PL_enq_L12m',
#  'time_since_recent_enq',
#  'enq_L3m',
#  'NETMONTHLYINCOME',
#  'Time_With_Curr_Empr',
#  'pct_currentBal_all_TL',
#  'CC_Flag',
#  'PL_Flag',
#  'pct_PL_enq_L6m_of_ever',
#  'pct_CC_enq_L6m_of_ever',
#  'HL_Flag',
#  'GL_Flag']

# %%
# Final features
features = columns_to_be_kept + ['MARITALSTATUS', 'EDUCATION', 'GENDER', 'last_prod_enq2', 'first_prod_enq2']
df = df[features + ['Approved_Flag']]

# %% [markdown]
# 3. **Data Encoding**:

# %%
# Label encoding for the categorical features
['MARITALSTATUS', 'EDUCATION', 'GENDER' , 'last_prod_enq2' ,'first_prod_enq2']
# Out:
# ['MARITALSTATUS', 'EDUCATION', 'GENDER', 'last_prod_enq2', 'first_prod_enq2']

# %%
df['MARITALSTATUS'].unique()    
df['EDUCATION'].unique()
df['GENDER'].unique()
df['last_prod_enq2'].unique()
df['first_prod_enq2'].unique()
# Out:
# array(['PL', 'ConsumerLoan', 'others', 'AL', 'HL', 'CC'], dtype=object)

# %%
df.loc[df['EDUCATION'] == 'SSC',['EDUCATION']]              = 1
df.loc[df['EDUCATION'] == '12TH',['EDUCATION']]             = 2
df.loc[df['EDUCATION'] == 'GRADUATE',['EDUCATION']]         = 3
df.loc[df['EDUCATION'] == 'UNDER GRADUATE',['EDUCATION']]   = 3
df.loc[df['EDUCATION'] == 'POST-GRADUATE',['EDUCATION']]    = 4
df.loc[df['EDUCATION'] == 'OTHERS',['EDUCATION']]           = 1
df.loc[df['EDUCATION'] == 'PROFESSIONAL',['EDUCATION']]     = 3

# %%
df['EDUCATION'].value_counts()
df['EDUCATION'] = df['EDUCATION'].astype(int)

# %%
df_encoded = pd.get_dummies(df, columns=['MARITALSTATUS','GENDER', 'last_prod_enq2' ,'first_prod_enq2'])



df_encoded.info()
k = df_encoded.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42064 entries, 0 to 42063
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pct_tl_open_L6M               42064 non-null  float64
#  1   pct_tl_closed_L6M             42064 non-null  float64
#  2   Tot_TL_closed_L12M            42064 non-null  int64
#  3   pct_tl_closed_L12M            42064 non-null  float64
#  4   Tot_Missed_Pmnt               42064 non-null  int64
#  5   CC_TL                         42064 non-null  int64
#  6   Home_TL                       42064 non-null  int64
#  7   PL_TL                         42064 non-null  int64
#  8   Secured_TL                    42064 non-null  int64
#  9   Unsecured_TL                  42064 non-null  int64
#  10  Other_TL                      42064 non-null  int64
#  11  Age_Oldest_TL                 42064 non-null  int64
#  12  Age_Newest_TL                 42064 non-null  int64
#  13  time_since_recent_payment     42064 non-null  int64
#  14  max_recent_level_of_deliq     42064 non-null  int64
#  15  num_deliq_6_12mts             42064 non-null  int64
#  16  num_times_60p_dpd             42064 non-null  int64
#  17  num_std_12mts                 42064 non-null  int64
#  18  num_sub                       42064 non-null  int64
#  19  num_sub_6mts                  42064 non-null  int64
#  20  num_sub_12mts                 42064 non-null  int64
#  21  num_dbt                       42064 non-null  int64
#  22  num_dbt_12mts                 42064 non-null  int64
#  23  num_lss                       42064 non-null  int64
#  24  num_lss_12mts                 42064 non-null  int64
#  25  recent_level_of_deliq         42064 non-null  int64
#  26  CC_enq_L12m                   42064 non-null  int64
#  27  PL_enq_L12m                   42064 non-null  int64
#  28  time_since_recent_enq         42064 non-null  int64
#  29  enq_L3m                       42064 non-null  int64
#  30  NETMONTHLYINCOME              42064 non-null  int64
#  31  Time_With_Curr_Empr           42064 non-null  int64
#  32  pct_currentBal_all_TL         42064 non-null  float64
#  33  CC_Flag                       42064 non-null  int64
#  34  PL_Flag                       42064 non-null  int64
#  35  pct_PL_enq_L6m_of_ever        42064 non-null  float64
#  36  pct_CC_enq_L6m_of_ever        42064 non-null  float64
#  37  HL_Flag                       42064 non-null  int64
#  38  GL_Flag                       42064 non-null  int64
#  39  EDUCATION                     42064 non-null  int64
#  40  Approved_Flag                 42064 non-null  object
#  41  MARITALSTATUS_Married         42064 non-null  bool
#  42  MARITALSTATUS_Single          42064 non-null  bool
#  43  GENDER_F                      42064 non-null  bool
#  44  GENDER_M                      42064 non-null  bool
#  45  last_prod_enq2_AL             42064 non-null  bool
#  46  last_prod_enq2_CC             42064 non-null  bool
#  47  last_prod_enq2_ConsumerLoan   42064 non-null  bool
#  48  last_prod_enq2_HL             42064 non-null  bool
#  49  last_prod_enq2_PL             42064 non-null  bool
#  50  last_prod_enq2_others         42064 non-null  bool
#  51  first_prod_enq2_AL            42064 non-null  bool
#  52  first_prod_enq2_CC            42064 non-null  bool
#  53  first_prod_enq2_ConsumerLoan  42064 non-null  bool
#  54  first_prod_enq2_HL            42064 non-null  bool
#  55  first_prod_enq2_PL            42064 non-null  bool
#  56  first_prod_enq2_others        42064 non-null  bool
# dtypes: bool(16), float64(6), int64(34), object(1)
# memory usage: 13.8+ MB

# %%
k
# Out:
#        pct_tl_open_L6M  pct_tl_closed_L6M  Tot_TL_closed_L12M  \
# count     42064.000000       42064.000000        42064.000000
# mean          0.179032           0.097783            0.825504
# std           0.278043           0.210957            1.537208
# min           0.000000           0.000000            0.000000
# 25%           0.000000           0.000000            0.000000
# 50%           0.000000           0.000000            0.000000
# 75%           0.333000           0.100000            1.000000
# max           1.000000           1.000000           33.000000
#
#        pct_tl_closed_L12M  Tot_Missed_Pmnt         CC_TL       Home_TL  \
# count        42064.000000     42064.000000  42064.000000  42064.000000
# mean             0.160365         0.525746      0.145921      0.076241
# std              0.258831         1.106442      0.549314      0.358582
# min              0.000000         0.000000      0.000000      0.000000
# 25%              0.000000         0.000000      0.000000      0.000000
# 50%              0.000000         0.000000      0.000000      0.000000
# 75%              0.250000         1.000000      0.000000      0.000000
# max              1.000000        34.000000     27.000000     10.000000
#
#               PL_TL    Secured_TL  Unsecured_TL  ...  NETMONTHLYINCOME  \
# count  42064.000000  42064.000000  42064.000000  ...      4.206400e+04
# mean       0.328000      2.921334      2.341646  ...      2.692990e+04
# std        0.916368      6.379764      3.405397  ...      2.084300e+04
# min        0.000000      0.000000      0.000000  ...      0.000000e+00
# 25%        0.000000      0.000000      0.000000  ...      1.800000e+04
# 50%        0.000000      1.000000      1.000000  ...      2.400000e+04
# 75%        0.000000      3.000000      3.000000  ...      3.100000e+04
# max       29.000000    235.000000     55.000000  ...      2.500000e+06
#
#        Time_With_Curr_Empr  pct_currentBal_all_TL       CC_Flag       PL_Flag  \
# count         42064.000000           42064.000000  42064.000000  42064.000000
# mean            110.345783               0.883693      0.102962      0.193063
# std              75.629967              40.622275      0.303913      0.394707
# min               0.000000               0.000000      0.000000      0.000000
# 25%              61.000000               0.152000      0.000000      0.000000
# 50%              92.000000               0.600000      0.000000      0.000000
# 75%             131.000000               0.860000      0.000000      0.000000
# max            1020.000000            6327.500000      1.000000      1.000000
#
#        pct_PL_enq_L6m_of_ever  pct_CC_enq_L6m_of_ever       HL_Flag  \
# count            42064.000000            42064.000000  42064.000000
# mean                 0.195497                0.064186      0.252235
# std                  0.367414                0.225989      0.434300
# min                  0.000000                0.000000      0.000000
# 25%                  0.000000                0.000000      0.000000
# 50%                  0.000000                0.000000      0.000000
# 75%                  0.000000                0.000000      1.000000
# max                  1.000000                1.000000      1.000000
#
#             GL_Flag     EDUCATION
# count  42064.000000  42064.000000
# mean       0.056580      2.313689
# std        0.231042      0.871070
# min        0.000000      1.000000
# 25%        0.000000      2.000000
# 50%        0.000000      2.000000
# 75%        0.000000      3.000000
# max        1.000000      4.000000
#
# [8 rows x 40 columns]

# %%
#df_encoded.to_excel('only_imp_final_features.xlsx', index=False)

# %% [markdown]
# 4. **Machine Learning Model Fitting**:

# %%
from sklearn.preprocessing import StandardScaler

# %%
y = df_encoded['Approved_Flag']
x = df_encoded.drop(['Approved_Flag'], axis=1)

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
# 1. Random Forest
rf_classifier = RandomForestClassifier(n_estimators = 200, random_state=42)
rf_classifier.fit(x_train, y_train)

y_pred = rf_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)

print ()
print(f'Accuracy: {accuracy}')
print ()
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.7626292642339237
#
# Class p1:
# Precision: 0.8385167464114832
# Recall: 0.6913214990138067
# F1 Score: 0.7578378378378378
#
# Class p2:
# Precision: 0.7924464677120215
# Recall: 0.931615460852329
# F1 Score: 0.8564139941690961
#
# Class p3:
# Precision: 0.4448051948051948
# Recall: 0.20679245283018868
# F1 Score: 0.28232869654817105
#
# Class p4:
# Precision: 0.7194174757281553
# Recall: 0.7201166180758017
# F1 Score: 0.7197668771248178

# %%
# 2.Xgboost
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

# %%
xgb_classifier = xgb.XGBClassifier(objective='multi:softmax',  num_class=4)

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# %%
xgb_classifier.fit(x_train, y_train)
y_pred = xgb_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print ()
print(f'Accuracy: {accuracy:.2f}')
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.77
#
# Class p1:
# Precision: 0.8275862068965517
# Recall: 0.757396449704142
# F1 Score: 0.7909371781668384
#
# Class p2:
# Precision: 0.8219885958660014
# Recall: 0.914370664023786
# F1 Score: 0.8657220606174346
#
# Class p3:
# Precision: 0.4447004608294931
# Recall: 0.29132075471698116
# F1 Score: 0.35202918376652986
#
# Class p4:
# Precision: 0.7283582089552239
# Recall: 0.7113702623906706
# F1 Score: 0.7197640117994101

# %%
# 3.decision tree C.
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier(max_depth=20, min_samples_split=10)
dt_model.fit(x_train, y_train)
y_pred = dt_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print ()
print(f"Accuracy: {accuracy:.2f}")
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.71
#
# Class p1:
# Precision: 0.7217741935483871
# Recall: 0.7061143984220908
# F1 Score: 0.7138584247258226
#
# Class p2:
# Precision: 0.8062645011600929
# Recall: 0.8265609514370664
# F1 Score: 0.8162865811882157
#
# Class p3:
# Precision: 0.34755134281200634
# Recall: 0.3320754716981132
# F1 Score: 0.3396372057120803
#
# Class p4:
# Precision: 0.6449643947100712
# Recall: 0.6161321671525753
# F1 Score: 0.6302186878727635

# %% [markdown]
# ## Since XGBoost is working the best among our options, let's just tweak its parameter to make it work even better.

# %% [markdown]
# 5. **Model Improvement**:

# %%
# Hyperparameter tuning for xgboost (Used in the session)

# Define the hyperparameter grid
param_grid = {
'colsample_bytree': [0.1, 0.3, 0.5, 0.7, 0.9],
'learning_rate'   : [0.001, 0.01, 0.1,0.5, 1],
'max_depth'       : [3, 5, 8, 10],
'alpha'           : [1, 10, 100],
'n_estimators'    : [10,50,100]
}

index = 0

answers_grid = {
 'combination'       :[],
 'train_Accuracy'    :[],
 'test_Accuracy'     :[],
 'colsample_bytree'  :[],
 'learning_rate'     :[],
 'max_depth'         :[],
 'alpha'             :[],
 'n_estimators'      :[]

 }

# %%
for colsample_bytree in param_grid['colsample_bytree']:
   for learning_rate in param_grid['learning_rate']:
     for max_depth in param_grid['max_depth']:
       for alpha in param_grid['alpha']:
           for n_estimators in param_grid['n_estimators']:

               index = index + 1

               # Define and train the XGBoost model
               model = xgb.XGBClassifier(objective='multi:softmax',  
                                        num_class=4,
                                        colsample_bytree = colsample_bytree,
                                        learning_rate = learning_rate,
                                        max_depth = max_depth,
                                        alpha = alpha,
                                        n_estimators = n_estimators)



               y = df_encoded['Approved_Flag']
               x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

               label_encoder = LabelEncoder()
               y_encoded = label_encoder.fit_transform(y)


               x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)


               model.fit(x_train, y_train)



               # Predict on training and testing sets
               y_pred_train = model.predict(x_train)
               y_pred_test = model.predict(x_test)


               # Calculate train and test results
               train_accuracy =  accuracy_score (y_train, y_pred_train)
               test_accuracy  =  accuracy_score (y_test , y_pred_test)



               # Include into the lists
               answers_grid ['combination']   .append(index)
               answers_grid ['train_Accuracy']    .append(train_accuracy)
               answers_grid ['test_Accuracy']     .append(test_accuracy)
               answers_grid ['colsample_bytree']   .append(colsample_bytree)
               answers_grid ['learning_rate']      .append(learning_rate)
               answers_grid ['max_depth']          .append(max_depth)
               answers_grid ['alpha']              .append(alpha)
               answers_grid ['n_estimators']       .append(n_estimators)


               # Print results for this combination
               print(f"Combination {index}")
               print(f"colsample_bytree: {colsample_bytree}, learning_rate: {learning_rate}, max_depth: {max_depth}, alpha: {alpha}, n_estimators: {n_estimators}")
               print(f"Train Accuracy: {train_accuracy:.2f}")
               print(f"Test Accuracy : {test_accuracy :.2f}")
               print("-" * 30)
# Out:
# Combination 1
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 2
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 3
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 4
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 5
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 6
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 7
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 8
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 9
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 10
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 11
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 12
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 13
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 14
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 15
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 16
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 17
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 18
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 19
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 20
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 21
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 22
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 23
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 24
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 25
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 26
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 27
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 28
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 29
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 30
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 31
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 32
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 33
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 34
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 35
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 36
# colsample_bytree: 0.1, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 37
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 38
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 39
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 40
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 41
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 42
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 43
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 44
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 45
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 46
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 47
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 48
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 49
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 50
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 51
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 52
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 53
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 54
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 55
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 56
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 57
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 58
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 59
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 60
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 61
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 62
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 63
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 64
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 65
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 66
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.63
# Test Accuracy : 0.61
# ------------------------------
# Combination 67
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 68
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 69
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 70
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 71
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 72
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 73
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 74
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 75
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 76
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.61
# ------------------------------
# Combination 77
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 78
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 79
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 80
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 81
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 82
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 83
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 84
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.74
# Test Accuracy : 0.72
# ------------------------------
# Combination 85
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 86
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 87
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.71
# ------------------------------
# Combination 88
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 89
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 90
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 91
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 92
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy : 0.67
# ------------------------------
# Combination 93
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.72
# ------------------------------
# Combination 94
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 95
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 96
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.71
# ------------------------------
# Combination 97
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 98
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 99
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 100
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.62
# ------------------------------
# Combination 101
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy : 0.67
# ------------------------------
# Combination 102
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.71
# ------------------------------
# Combination 103
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.62
# Test Accuracy : 0.61
# ------------------------------
# Combination 104
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 105
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 106
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.61
# Test Accuracy : 0.60
# ------------------------------
# Combination 107
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 108
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 109
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 110
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.74
# ------------------------------
# Combination 111
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.76
# ------------------------------
# Combination 112
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 113
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 114
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.76
# ------------------------------
# Combination 115
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 116
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 117
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# ------------------------------
# Combination 118
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 119
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.74
# ------------------------------
# Combination 120
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.82
# Test Accuracy : 0.76
# ------------------------------
# Combination 121
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 122
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.74
# ------------------------------
# Combination 123
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.76
# ------------------------------
# Combination 124
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 125
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 126
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# ------------------------------
# Combination 127
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.67
# ------------------------------
# Combination 128
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.83
# Test Accuracy : 0.73
# ------------------------------
# Combination 129
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.90
# Test Accuracy : 0.75
# ------------------------------
# Combination 130
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 131
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.74
# ------------------------------
# Combination 132
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.76
# ------------------------------
# Combination 133
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 134
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 135
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 136
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.67
# ------------------------------
# Combination 137
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.86
# Test Accuracy : 0.73
# ------------------------------
# Combination 138
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.93
# Test Accuracy : 0.75
# ------------------------------
# Combination 139
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 140
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.74
# ------------------------------
# Combination 141
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.76
# ------------------------------
# Combination 142
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 143
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 144
# colsample_bytree: 0.1, learning_rate: 0.5, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 145
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.70
# ------------------------------
# Combination 146
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.75
# ------------------------------
# Combination 147
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.76
# ------------------------------
# Combination 148
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.70
# ------------------------------
# Combination 149
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.75
# ------------------------------
# Combination 150
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.76
# ------------------------------
# Combination 151
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 152
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 153
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 154
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.70
# ------------------------------
# Combination 155
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy : 0.75
# ------------------------------
# Combination 156
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.86
# Test Accuracy : 0.76
# ------------------------------
# Combination 157
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 158
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.75
# ------------------------------
# Combination 159
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy : 0.77
# ------------------------------
# Combination 160
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 161
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 162
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 163
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.74
# Test Accuracy : 0.69
# ------------------------------
# Combination 164
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.89
# Test Accuracy : 0.73
# ------------------------------
# Combination 165
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.94
# Test Accuracy : 0.75
# ------------------------------
# Combination 166
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 167
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.76
# ------------------------------
# Combination 168
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.82
# Test Accuracy : 0.77
# ------------------------------
# Combination 169
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 170
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 171
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 172
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.69
# ------------------------------
# Combination 173
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.92
# Test Accuracy : 0.73
# ------------------------------
# Combination 174
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.97
# Test Accuracy : 0.74
# ------------------------------
# Combination 175
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 176
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.75
# ------------------------------
# Combination 177
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy : 0.76
# ------------------------------
# Combination 178
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 179
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 180
# colsample_bytree: 0.1, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 181
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 182
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.65
# Test Accuracy : 0.65
# ------------------------------
# Combination 183
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.65
# Test Accuracy : 0.65
# ------------------------------
# Combination 184
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 185
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.65
# Test Accuracy : 0.65
# ------------------------------
# Combination 186
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.65
# Test Accuracy : 0.65
# ------------------------------
# Combination 187
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 188
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.64
# Test Accuracy : 0.64
# ------------------------------
# Combination 189
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.65
# Test Accuracy : 0.64
# ------------------------------
# Combination 190
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 191
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 192
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 193
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 194
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 195
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 196
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 197
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.65
# Test Accuracy : 0.64
# ------------------------------
# Combination 198
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.65
# Test Accuracy : 0.64
# ------------------------------
# Combination 199
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.69
# ------------------------------
# Combination 200
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy : 0.68
# ------------------------------
# Combination 201
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy : 0.69
# ------------------------------
# Combination 202
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 203
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 204
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 205
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 206
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.65
# Test Accuracy : 0.64
# ------------------------------
# Combination 207
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.65
# Test Accuracy : 0.65
# ------------------------------
# Combination 208
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.74
# Test Accuracy : 0.70
# ------------------------------
# Combination 209
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.72
# Test Accuracy : 0.69
# ------------------------------
# Combination 210
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy : 0.69
# ------------------------------
# Combination 211
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 212
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 213
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 214
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 215
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.65
# Test Accuracy : 0.64
# ------------------------------
# Combination 216
# colsample_bytree: 0.3, learning_rate: 0.001, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.65
# Test Accuracy : 0.65
# ------------------------------
# Combination 217
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 218
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 219
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 220
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 221
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 222
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 223
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 224
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.65
# Test Accuracy : 0.65
# ------------------------------
# Combination 225
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 226
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.69
# ------------------------------
# Combination 227
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 228
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 229
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 230
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 231
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 232
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.66
# Test Accuracy : 0.66
# ------------------------------
# Combination 233
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 234
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 235
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.70
# ------------------------------
# Combination 236
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy : 0.69
# ------------------------------
# Combination 237
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy : 0.70
# ------------------------------
# Combination 238
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 239
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy : 0.68
# ------------------------------
# Combination 240
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 241
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 242
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 243
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 244
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.74
# Test Accuracy : 0.70
# ------------------------------
# Combination 245
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.70
# ------------------------------
# Combination 246
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.70
# ------------------------------
# Combination 247
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 248
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy : 0.69
# ------------------------------
# Combination 249
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 250
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.67
# Test Accuracy : 0.66
# ------------------------------
# Combination 251
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.66
# Test Accuracy : 0.65
# ------------------------------
# Combination 252
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.67
# Test Accuracy : 0.67
# ------------------------------
# Combination 253
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.69
# ------------------------------
# Combination 254
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 255
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 256
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.69
# Test Accuracy : 0.69
# ------------------------------
# Combination 257
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy : 0.73
# ------------------------------
# Combination 258
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 259
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.67
# ------------------------------
# Combination 260
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 261
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 262
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 263
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.75
# ------------------------------
# Combination 264
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.77
# ------------------------------
# Combination 265
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.71
# Test Accuracy : 0.70
# ------------------------------
# Combination 266
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy : 0.74
# ------------------------------
# Combination 267
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 268
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.68
# Test Accuracy : 0.68
# ------------------------------
# Combination 269
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy : 0.72
# ------------------------------
# Combination 270
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 271
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.72
# ------------------------------
# Combination 272
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy : 0.75
# ------------------------------
# Combination 273
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.86
# Test Accuracy : 0.77
# ------------------------------
# Combination 274
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.72
# Test Accuracy : 0.71
# ------------------------------
# Combination 275
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.77
# ...
# Combination 809
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 810
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 811
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.81
# Test Accuracy : 0.77
# ------------------------------
# Combination 812
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.84
# Test Accuracy : 0.78
# ------------------------------
# Combination 813
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.88
# Test Accuracy : 0.77
# ------------------------------
# Combination 814
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 815
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy : 0.78
# ------------------------------
# Combination 816
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy : 0.78
# ------------------------------
# Combination 817
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 818
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.77
# ------------------------------
# Combination 819
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 820
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.84
# Test Accuracy : 0.77
# ------------------------------
# Combination 821
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.90
# Test Accuracy : 0.77
# ------------------------------
# Combination 822
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.94
# Test Accuracy : 0.77
# ------------------------------
# Combination 823
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.80
# Test Accuracy : 0.77
# ------------------------------
# Combination 824
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy : 0.78
# ------------------------------
# Combination 825
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.85
# Test Accuracy : 0.78
# ------------------------------
# Combination 826
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.74
# ------------------------------
# Combination 827
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 828
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 829
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.76
# Test Accuracy : 0.76
# ------------------------------
# Combination 830
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.78
# ------------------------------
# Combination 831
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy : 0.78
# ------------------------------
# Combination 832
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.76
# Test Accuracy : 0.75
# ------------------------------
# Combination 833
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy : 0.78
# ------------------------------
# Combination 834
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy : 0.78
# ------------------------------
# Combination 835
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# ------------------------------
# Combination 836
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 837
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 838
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 839
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.84
# Test Accuracy : 0.78
# ------------------------------
# Combination 840
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.89
# Test Accuracy : 0.77
# ------------------------------
# Combination 841
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 842
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy : 0.78
# ------------------------------
# Combination 843
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.84
# Test Accuracy : 0.77
# ------------------------------
# Combination 844
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 845
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 846
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 847
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.84
# Test Accuracy : 0.77
# ------------------------------
# Combination 848
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.96
# Test Accuracy : 0.77
# ------------------------------
# Combination 849
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 1.00
# Test Accuracy : 0.77
# ------------------------------
# Combination 850
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.80
# Test Accuracy : 0.78
# ------------------------------
# Combination 851
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.88
# Test Accuracy : 0.77
# ------------------------------
# Combination 852
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.92
# Test Accuracy : 0.77
# ------------------------------
# Combination 853
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 854
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 855
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 856
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.90
# Test Accuracy : 0.77
# ------------------------------
# Combination 857
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 858
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 859
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.82
# Test Accuracy : 0.78
# ------------------------------
# Combination 860
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.91
# Test Accuracy : 0.77
# ------------------------------
# Combination 861
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.94
# Test Accuracy : 0.77
# ------------------------------
# Combination 862
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 863
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 864
# colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 865
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 866
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy : 0.78
# ------------------------------
# Combination 867
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy : 0.77
# ------------------------------
# Combination 868
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 869
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy : 0.78
# ------------------------------
# Combination 870
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.82
# Test Accuracy : 0.78
# ------------------------------
# Combination 871
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 10
# Train Accuracy: 0.77
# Test Accuracy : 0.76
# ------------------------------
# Combination 872
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy : 0.77
# ------------------------------
# Combination 873
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy : 0.77
# ------------------------------
# Combination 874
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 10
# Train Accuracy: 0.80
# Test Accuracy : 0.78
# ------------------------------
# Combination 875
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.89
# Test Accuracy : 0.77
# ------------------------------
# Combination 876
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.95
# Test Accuracy : 0.77
# ------------------------------
# Combination 877
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 10
# Train Accuracy: 0.79
# Test Accuracy : 0.78
# ------------------------------
# Combination 878
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.84
# Test Accuracy : 0.77
# ------------------------------
# Combination 879
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.88
# Test Accuracy : 0.77
# ------------------------------
# Combination 880
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 881
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 882
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 883
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 10
# Train Accuracy: 0.88
# Test Accuracy : 0.77
# ------------------------------
# Combination 884
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 885
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 886
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 10
# Train Accuracy: 0.82
# Test Accuracy : 0.77
# ------------------------------
# Combination 887
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.92
# Test Accuracy : 0.77
# ------------------------------
# Combination 888
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.95
# Test Accuracy : 0.76
# ------------------------------
# Combination 889
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 890
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 891
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 892
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 10
# Train Accuracy: 0.93
# Test Accuracy : 0.76
# ------------------------------
# Combination 893
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 894
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 1.00
# Test Accuracy : 0.76
# ------------------------------
# Combination 895
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 10
# Train Accuracy: 0.84
# Test Accuracy : 0.77
# ------------------------------
# Combination 896
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.94
# Test Accuracy : 0.77
# ------------------------------
# Combination 897
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.97
# Test Accuracy : 0.77
# ------------------------------
# Combination 898
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 10
# Train Accuracy: 0.78
# Test Accuracy : 0.77
# ------------------------------
# Combination 899
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
# Combination 900
# colsample_bytree: 0.9, learning_rate: 1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy : 0.77
# ------------------------------
